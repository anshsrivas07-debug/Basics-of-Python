# %% [markdown]
# <a href="https://colab.research.google.com/github/anshsrivas07-debug/Basics-of-Python/blob/main/practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA using PYTHON
# #expet -1
# python basics
# #ANSH SRIVASTAVA
# #PRN-25070123015
# #BATCH-ENTC 2025-29

# %%
# first program
print("hello world")
# Out:
# hello world

# %%
print("bro i am so cooked")
# Out:
# bro i am so cooked

# %%
a="hello"
print(a)
# Out:
# hello

# %%
# many statements
print("whatsuppp yooo")
print("i am done")
print("yeyeyeyeyeyye")
# Out:
# whatsuppp yooo
# i am done
# yeyeyeyeyeyye

# %%
print("kse ho");print("theek hoon")
# Out:
# kse ho
# theek hoon

# %%
print("hello world",end=" ")
print("ek hi line me print krunga")
# Out:
# hello world ek hi line me print krunga

# %%
print(2)
print(4)
print(2824)
# Out:
# 2
# 4
# 2824

# %%
# variables
x="ansh"
y="loves her"
print(x)
print(y)
# Out:
# ansh
# loves her

# %%
# case sensitive
a=4
A="SHARUKH KHAN"
print(a)
print(A)
# Out:
# 4
# SHARUKH KHAN

# %%
# may value to multipile variables
x,y,z= "orange","banana",34
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# 34

# %%
a=20
b=5

# %%
# subtraction
print("subtraction =",a-b)
# Out:
# subtraction = 15

# %%
# multiplication
print("multiplication =",a*b)
# Out:
# multiplication = 100

# %%
#division
print("division is =",a/b)
# Out:
# division is = 4.0

# %%
# Understanding data types
x=10
y=3.14
z="PYTHON"
flag=True
c=3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(flag))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
name= input("Enter your name:")
print("hello",name)
# Out:
# Enter your name:mauli
# hello mauli

# %%
#simple calculator
a=int(input("enter first number:"))
b=int(input("enter second number"))
print("addition=",a+b)
print("subtraction",a-b)
print("division",a/b)
print("multiplication",a*b)
# Out:
# enter first number:20
# enter second number5
# addition= 25
# subtraction 15
# division 4.0
# multiplication 100

# %%
#average and total markes obtained
maths=int(input("enter m1"))
phy=int(input("enter m2"))
chem=int(input("enter m3"))
eng=int(input("enter m4"))
hindi=int(input("enter m5"))
sum=maths+phy+eng+hindi+chem
print("total of 5 subject",maths+phy+chem+eng+hindi)
print("average",sum/5)
# Out:
# enter m160
# enter m280
# enter m370
# enter m465
# enter m548
# total of 5 subject 323
# average 64.6

# %%
# area of rectangle
length=int(input("enter length"))
breadth=int(input("enter breadth"))
print("area of rectangle=",length*breadth)
# Out:
# enter length16
# enter breadth16
# area of rectangle= 256

# %%
# area of circle
radius=int(input("enter radius"))
print("area of circle",3.14*radius*radius)
# Out:
# enter radius34
# area of circle 3629.84
